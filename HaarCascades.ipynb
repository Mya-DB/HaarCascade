# %% [markdown]
# import cv2
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
imagePath = "/home/mya/Downloads/00000/00447.png"
image = cv2.imread(imagePath)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
imagePath = "/home/mya/Downloads/00000/00453.png"
image2 = cv2.imread(imagePath)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
plt.imshow(image2)

# %%
print(cv2.data.haarcascades)
# Out:
# /home/mya/anaconda3/lib/python3.8/site-packages/cv2/data/

# %%
fd = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
def get_detected_face (face):  
    face_img = face.copy()  
    fr = fd.detectMultiScale(face_img)  
    for (x,y,width,height) in fr:  
        cv2.rectangle(face_img, (x,y), (x + width, y+height), (255,255,77), 10)                
    return face_img

# %%
result = get_detected_face(image2)

# %%
plt.imshow(result, cmap = "gray")

# %%
result2 = get_detected_face(image)
plt.imshow(result2, cmap = "gray")

# %%
path = "/home/mya/Downloads/obamas.jpeg"
obama = cv2.imread(path)
obama = cv2.cvtColor(obama, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(obama)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/Black-People-Can-Get-Melanoma-Too.jpg"
two = cv2.imread(path)
two = cv2.cvtColor(two, cv2.COLOR_BGR2RGB)
#plt.imshow(obama)
result3 = get_detected_face(two)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/twowhitewomen.jpeg"
twowhite = cv2.imread(path)
twowhite = cv2.cvtColor(twowhite, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(twowhite)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/onewoman.jpeg"
onewoman = cv2.imread(path)
onewoman = cv2.cvtColor(onewoman, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(onewoman)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/darknlight.jpeg"
blacknwhite = cv2.imread(path)
blacknwhite = cv2.cvtColor(blacknwhite, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(blacknwhite)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/littleboys.jpg"
littleboys = cv2.imread(path)
littleboys= cv2.cvtColor(littleboys, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(littleboys)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/albinoandblackwoman.jpeg"
albino = cv2.imread(path)
albino= cv2.cvtColor(albino, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(albino)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/littleboys2.jpg"
littleboys2 = cv2.imread(path)
littleboys2= cv2.cvtColor(littleboys2, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(littleboys2)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/istockphoto-1146473249-612x612.jpg"
groupofpeople = cv2.imread(path)
groupofpeople= cv2.cvtColor(groupofpeople, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(groupofpeople)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/groupofwhitepeople.jpeg"
groupofpeople2 = cv2.imread(path)
groupofpeople2= cv2.cvtColor(groupofpeople2, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(groupofpeople2)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/groups-TW-600x321.jpg"
groupofpeople3 = cv2.imread(path)
groupofpeople3= cv2.cvtColor(groupofpeople3, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(groupofpeople3)
plt.imshow(result3, cmap = "gray")

# %%
path = "/home/mya/Downloads/istockphoto-1308419138-170667a.jpg"
groupofpeople4 = cv2.imread(path)
groupofpeople4= cv2.cvtColor(groupofpeople4, cv2.COLOR_BGR2RGB)
result3 = get_detected_face(groupofpeople4)
plt.imshow(result3, cmap = "gray")
